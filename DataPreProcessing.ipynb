# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('data/penguins_raw.csv')

# %% [markdown]
# ### Data Investigation: Initial Overview
#
# Let's start by displaying the first few rows of the DataFrame to get a glimpse of the data, its columns, and the format.

# %%
display(df.head())
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion    Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  2007-11-11
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  2007-11-11
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  2007-11-16
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  2007-11-16
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  2007-11-16
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                39.1               18.7                181.0         3750.0
# 1                39.5               17.4                186.0         3800.0
# 2                40.3               18.0                195.0         3250.0
# 3                 NaN                NaN                  NaN            NaN
# 4                36.7               19.3                193.0         3450.0
#
#       Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0    MALE                NaN                NaN
# 1  FEMALE            8.94956          -24.69454
# 2  FEMALE            8.36821          -25.33302
# 3     NaN                NaN                NaN
# 4  FEMALE            8.76651          -25.32426
#
#                          Comments
# 0  Not enough blood for isotopes.
# 1                             NaN
# 2                             NaN
# 3              Adult not sampled.
# 4                             NaN

# %% [markdown]
# Next, we'll check the DataFrame's information, which includes the column names, non-null counts, and data types. This helps us understand the structure and identify potential issues like incorrect data types or columns with many missing values.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   studyName            344 non-null    object
#  1   Sample Number        344 non-null    int64
#  2   Species              344 non-null    object
#  3   Region               344 non-null    object
#  4   Island               344 non-null    object
#  5   Stage                344 non-null    object
#  6   Individual ID        344 non-null    object
#  7   Clutch Completion    344 non-null    object
#  8   Date Egg             344 non-null    object
#  9   Culmen Length (mm)   342 non-null    float64
#  10  Culmen Depth (mm)    342 non-null    float64
#  11  Flipper Length (mm)  342 non-null    float64
#  12  Body Mass (g)        342 non-null    float64
#  13  Sex                  333 non-null    object
#  14  Delta 15 N (o/oo)    330 non-null    float64
#  15  Delta 13 C (o/oo)    331 non-null    float64
#  16  Comments             54 non-null     object
# dtypes: float64(6), int64(1), object(10)
# memory usage: 45.8+ KB
# None

# %% [markdown]
# Finally, let's count the number of missing values for each column. This is crucial for deciding how to handle missing data during preprocessing.

# %%
print(df.isnull().sum())
# Out:
# studyName                0
# Sample Number            0
# Species                  0
# Region                   0
# Island                   0
# Stage                    0
# Individual ID            0
# Clutch Completion        0
# Date Egg                 0
# Culmen Length (mm)       2
# Culmen Depth (mm)        2
# Flipper Length (mm)      2
# Body Mass (g)            2
# Sex                     11
# Delta 15 N (o/oo)       14
# Delta 13 C (o/oo)       13
# Comments               290
# dtype: int64

# %% [markdown]
# Based on the high number of missing values, the 'Comments' column is not very useful and can be dropped.

# %%
# Drop the 'Comments' column due to a high number of missing values
df = df.drop('Comments', axis=1)

# Display the number of missing values after dropping 'Comments'
print(df.isnull().sum())
# Out:
# studyName               0
# Sample Number           0
# Species                 0
# Region                  0
# Island                  0
# Stage                   0
# Individual ID           0
# Clutch Completion       0
# Date Egg                0
# Culmen Length (mm)      2
# Culmen Depth (mm)       2
# Flipper Length (mm)     2
# Body Mass (g)           2
# Sex                    11
# Delta 15 N (o/oo)      14
# Delta 13 C (o/oo)      13
# dtype: int64

# %% [markdown]
# Now, let's address the remaining missing values.
#
# For numerical features like 'Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Delta 15 N (o/oo)', and 'Delta 13 C (o/oo)', we can impute the missing values with the mean or median. Given the small number of missing values for some of these, the mean is a reasonable choice.
#
# For the categorical feature 'Sex', we will impute the missing values with the mode (the most frequent value).

# %%
# Impute numerical columns with the mean
numerical_cols = ['Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)']
for col in numerical_cols:
    df[col].fillna(df[col].mean(), inplace=True)

# Impute 'Sex' column with the mode
df['Sex'].fillna(df['Sex'].mode()[0], inplace=True)

# Display the number of missing values after imputation
print(df.isnull().sum())
# Out:
# studyName              0
# Sample Number          0
# Species                0
# Region                 0
# Island                 0
# Stage                  0
# Individual ID          0
# Clutch Completion      0
# Date Egg               0
# Culmen Length (mm)     0
# Culmen Depth (mm)      0
# Flipper Length (mm)    0
# Body Mass (g)          0
# Sex                    0
# Delta 15 N (o/oo)      0
# Delta 13 C (o/oo)      0
# dtype: int64
# /tmp/ipykernel_1406/3001037133.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)
# /tmp/ipykernel_1406/3001037133.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Sex'].fillna(df['Sex'].mode()[0], inplace=True)

# %% [markdown]
# Now that we've handled all missing values, the dataset is cleaner. Let's confirm the data types and look at some summary statistics.

# %%
print(df.info())
display(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   studyName            344 non-null    object
#  1   Sample Number        344 non-null    int64
#  2   Species              344 non-null    object
#  3   Region               344 non-null    object
#  4   Island               344 non-null    object
#  5   Stage                344 non-null    object
#  6   Individual ID        344 non-null    object
#  7   Clutch Completion    344 non-null    object
#  8   Date Egg             344 non-null    object
#  9   Culmen Length (mm)   344 non-null    float64
#  10  Culmen Depth (mm)    344 non-null    float64
#  11  Flipper Length (mm)  344 non-null    float64
#  12  Body Mass (g)        344 non-null    float64
#  13  Sex                  344 non-null    object
#  14  Delta 15 N (o/oo)    344 non-null    float64
#  15  Delta 13 C (o/oo)    344 non-null    float64
# dtypes: float64(6), int64(1), object(9)
# memory usage: 43.1+ KB
# None
#        Sample Number  Culmen Length (mm)  Culmen Depth (mm)  \
# count     344.000000          344.000000         344.000000
# mean       63.151163           43.921930          17.151170
# std        40.430199            5.443643           1.969027
# min         1.000000           32.100000          13.100000
# 25%        29.000000           39.275000          15.600000
# 50%        58.000000           44.250000          17.300000
# 75%        95.250000           48.500000          18.700000
# max       152.000000           59.600000          21.500000
#
#        Flipper Length (mm)  Body Mass (g)  Delta 15 N (o/oo)  \
# count           344.000000     344.000000         344.000000
# mean            200.915205    4201.754386           8.733382
# std              14.020657     799.613058           0.540392
# min             172.000000    2700.000000           7.632200
# 25%             190.000000    3550.000000           8.307415
# 50%             197.000000    4050.000000           8.687455
# 75%             213.000000    4750.000000           9.136170
# max             231.000000    6300.000000          10.025440
#
#        Delta 13 C (o/oo)
# count         344.000000
# mean          -25.686292
# std             0.778770
# min           -27.018540
# 25%           -26.285460
# 50%           -25.793660
# 75%           -25.089467
# max           -23.787670

# %% [markdown]
# Now that missing values are handled and we have an overview of the data types, let's investigate the unique values in the categorical columns. This will help us understand the distinct categories and identify potential areas for filtering or aggregation.

# %%
# Identify categorical columns (object type)
categorical_cols = df.select_dtypes(include='object').columns

print("Unique values and their counts for categorical columns:")
for col in categorical_cols:
    print(f"\n--- Column: {col} ---")
    print(df[col].value_counts())

# Also check the 'Date Egg' column, which appears to be an object type but represents dates.
# It should ideally be converted to a datetime object for any time-series analysis or filtering by date.
print("\n--- Column: Date Egg ---")
print(df['Date Egg'].value_counts())
# Out:
# Unique values and their counts for categorical columns:
#
# --- Column: studyName ---
# studyName
# PAL0910    120
# PAL0809    114
# PAL0708    110
# Name: count, dtype: int64
#
# --- Column: Species ---
# Species
# Adelie Penguin (Pygoscelis adeliae)          152
# Gentoo penguin (Pygoscelis papua)            124
# Chinstrap penguin (Pygoscelis antarctica)     68
# Name: count, dtype: int64
#
# --- Column: Region ---
# Region
# Anvers    344
# Name: count, dtype: int64
#
# --- Column: Island ---
# Island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64
#
# --- Column: Stage ---
# Stage
# Adult, 1 Egg Stage    344
# Name: count, dtype: int64
#
# --- Column: Individual ID ---
# Individual ID
# N6A1      3
# N6A2      3
# N13A2     3
# N13A1     3
# N8A2      3
#          ..
# N98A2     1
# N99A1     1
# N99A2     1
# N100A1    1
# N100A2    1
# Name: count, Length: 190, dtype: int64
#
# --- Column: Clutch Completion ---
# Clutch Completion
# Yes    308
# No      36
# Name: count, dtype: int64
#
# --- Column: Date Egg ---
# Date Egg
# 2007-11-27    18
# 2007-11-16    16
# 2008-11-09    16
# 2009-11-18    14
# 2008-11-13    12
# 2008-11-06    12
# 2008-11-04    12
# 2009-11-21    12
# 2008-11-14    10
# 2009-11-22    10
# 2009-11-15    10
# 2009-11-17    10
# 2009-11-16    10
# 2007-11-29    10
# 2009-11-27    10
# 2008-11-08     8
# 2007-11-12     8
# 2007-11-09     8
# 2007-11-28     8
# 2008-11-24     8
# 2008-11-03     8
# 2009-12-01     8
# 2009-11-25     6
# 2007-12-03     6
# 2009-11-23     6
# 2009-11-20     6
# 2007-11-13     6
# 2008-11-02     6
# 2008-11-15     4
# 2008-11-17     4
# 2007-11-10     4
# 2007-11-15     4
# 2007-11-19     4
# 2008-11-11     4
# 2007-11-30     4
# 2009-11-13     4
# 2007-11-21     4
# 2008-11-25     4
# 2009-11-09     4
# 2007-11-26     4
# 2009-11-10     4
# 2007-11-11     2
# 2008-11-07     2
# 2008-11-10     2
# 2008-11-05     2
# 2009-11-12     2
# 2009-11-14     2
# 2007-11-18     2
# 2007-11-22     2
# 2009-11-19     2
# Name: count, dtype: int64
#
# --- Column: Sex ---
# Sex
# MALE      179
# FEMALE    165
# Name: count, dtype: int64
#
# --- Column: Date Egg ---
# Date Egg
# 2007-11-27    18
# 2007-11-16    16
# 2008-11-09    16
# 2009-11-18    14
# 2008-11-13    12
# 2008-11-06    12
# 2008-11-04    12
# 2009-11-21    12
# 2008-11-14    10
# 2009-11-22    10
# 2009-11-15    10
# 2009-11-17    10
# 2009-11-16    10
# 2007-11-29    10
# 2009-11-27    10
# 2008-11-08     8
# 2007-11-12     8
# 2007-11-09     8
# 2007-11-28     8
# 2008-11-24     8
# 2008-11-03     8
# 2009-12-01     8
# 2009-11-25     6
# 2007-12-03     6
# 2009-11-23     6
# 2009-11-20     6
# 2007-11-13     6
# 2008-11-02     6
# 2008-11-15     4
# 2008-11-17     4
# 2007-11-10     4
# 2007-11-15     4
# 2007-11-19     4
# 2008-11-11     4
# 2007-11-30     4
# 2009-11-13     4
# 2007-11-21     4
# 2008-11-25     4
# 2009-11-09     4
# 2007-11-26     4
# 2009-11-10     4
# 2007-11-11     2
# 2008-11-07     2
# 2008-11-10     2
# 2008-11-05     2
# 2009-11-12     2
# 2009-11-14     2
# 2007-11-18     2
# 2007-11-22     2
# 2009-11-19     2
# Name: count, dtype: int64

# %% [markdown]
# Based on the unique values:
#
# *   **'Species'**: This is a key categorical variable that will likely be used for grouping or analysis. We might filter for specific species or aggregate metrics by species.
# *   **'Region'**, **'Island'**: These also look like good candidates for grouping or filtering, depending on the analysis goals.
# *   **'Stage'**, **'Clutch Completion'**, **'Sex'**: These are fairly clean and can be used directly or for filtering.
# *   **'studyName'**, **'Individual ID'**: These columns have many unique values, almost one per row. 'Individual ID' is an identifier and is likely not useful for direct analysis or aggregation unless we need to track specific individuals. 'studyName' has only a few unique values, so it could potentially be used for grouping or filtering if there are differences across studies.
# *   **'Date Egg'**: This column is currently an `object` type. It should be converted to a `datetime` object to enable time-based filtering or aggregation (e.g., daily, monthly counts).

# %%
# Convert 'Date Egg' to datetime
df['Date Egg'] = pd.to_datetime(df['Date Egg'])

# Verify the conversion
print("\n--- After converting 'Date Egg' to datetime ---")
print(df['Date Egg'].dtype)
print(df.info())
# Out:
# --- After converting 'Date Egg' to datetime ---
# datetime64[ns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   studyName            344 non-null    object
#  1   Sample Number        344 non-null    int64
#  2   Species              344 non-null    object
#  3   Region               344 non-null    object
#  4   Island               344 non-null    object
#  5   Stage                344 non-null    object
#  6   Individual ID        344 non-null    object
#  7   Clutch Completion    344 non-null    object
#  8   Date Egg             344 non-null    datetime64[ns]
#  9   Culmen Length (mm)   344 non-null    float64
#  10  Culmen Depth (mm)    344 non-null    float64
#  11  Flipper Length (mm)  344 non-null    float64
#  12  Body Mass (g)        344 non-null    float64
#  13  Sex                  344 non-null    object
#  14  Delta 15 N (o/oo)    344 non-null    float64
#  15  Delta 13 C (o/oo)    344 non-null    float64
# dtypes: datetime64[ns](1), float64(6), int64(1), object(8)
# memory usage: 43.1+ KB
# None

# %% [markdown]
# At this point, the need for further filtering or aggregation depends entirely on the specific questions we want to answer. We've cleaned up missing values and ensured `Date Egg` is in the correct format.
#
# **Possible next steps for filtering/aggregation could include:**
#
# 1.  **Filtering by Species or Island**: If we want to analyze a specific group of penguins.
# 2.  **Aggregating by Species, Island, or Date**: To see average culmen lengths, body masses, etc., for different groups or over time.
# 3.  **Feature Engineering**: Extracting year, month, or day from 'Date Egg' for time-series analysis.
#
# Let me know what kind of analysis you have in mind, and I can suggest specific filtering or aggregation steps!

# %% [markdown]
# Để minh họa quá trình tổng hợp (aggregation), chúng ta sẽ tính toán giá trị trung bình của các thuộc tính vật lý chính (chiều dài mỏ, độ sâu mỏ, chiều dài vây, và khối lượng cơ thể) cho mỗi loài chim cánh cụt trên từng hòn đảo. Điều này giúp chúng ta hiểu rõ hơn về sự khác biệt giữa các loài và ảnh hưởng của môi trường sống.

# %%
# Aggregation Example: Calculate mean physical attributes by Species and Island
agg_df = df.groupby(['Species', 'Island'])[['Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)']].mean().reset_index()

print("Mean physical attributes by Species and Island:")
display(agg_df)

# Another example: Count the number of penguins by Species and Island
count_df = df.groupby(['Species', 'Island']).size().reset_index(name='Count')
print("\nNumber of penguins by Species and Island:")
display(count_df)
# Out:
# Mean physical attributes by Species and Island:
#                                      Species     Island  Culmen Length (mm)  \
# 0        Adelie Penguin (Pygoscelis adeliae)     Biscoe           38.975000
# 1        Adelie Penguin (Pygoscelis adeliae)      Dream           38.501786
# 2        Adelie Penguin (Pygoscelis adeliae)  Torgersen           39.046576
# 3  Chinstrap penguin (Pygoscelis antarctica)      Dream           48.833824
# 4          Gentoo penguin (Pygoscelis papua)     Biscoe           47.475983
#
#    Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)
# 0          18.370455           188.795455    3709.659091
# 1          18.251786           189.732143    3688.392857
# 2          18.404830           191.382985    3715.899123
# 3          18.420588           195.823529    3733.088235
# 4          14.999606           217.055768    5068.965761
# Number of penguins by Species and Island:
#                                      Species     Island  Count
# 0        Adelie Penguin (Pygoscelis adeliae)     Biscoe     44
# 1        Adelie Penguin (Pygoscelis adeliae)      Dream     56
# 2        Adelie Penguin (Pygoscelis adeliae)  Torgersen     52
# 3  Chinstrap penguin (Pygoscelis antarctica)      Dream     68
# 4          Gentoo penguin (Pygoscelis papua)     Biscoe    124

# %% [markdown]
# Hãy cùng khám phá thêm các kỹ thuật tổng hợp khác để có cái nhìn toàn diện hơn về dữ liệu, bao gồm các số liệu thống kê mô tả như giá trị nhỏ nhất, lớn nhất, trung vị và độ lệch chuẩn, cũng như việc đếm số lượng các giá trị duy nhất.

# %%
# Aggregation Example: Calculate min, max, median, and std deviation of physical attributes by Species and Island
agg_stats_df = df.groupby(['Species', 'Island'])[['Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)']].agg(['min', 'max', 'median', 'std']).reset_index()

print("Min, Max, Median, and Std Deviation of physical attributes by Species and Island:")
display(agg_stats_df)
# Out:
# Min, Max, Median, and Std Deviation of physical attributes by Species and Island:
#                                      Species     Island Culmen Length (mm)  \
#                                                                        min
# 0        Adelie Penguin (Pygoscelis adeliae)     Biscoe               34.5
# 1        Adelie Penguin (Pygoscelis adeliae)      Dream               32.1
# 2        Adelie Penguin (Pygoscelis adeliae)  Torgersen               33.5
# 3  Chinstrap penguin (Pygoscelis antarctica)      Dream               40.9
# 4          Gentoo penguin (Pygoscelis papua)     Biscoe               40.9
#
#                          Culmen Depth (mm)                         \
#     max median       std               min   max median       std
# 0  45.6  38.70  2.480916              16.0  21.1  18.45  1.188820
# 1  44.1  38.55  2.465359              15.5  21.2  18.40  1.133617
# 2  46.0  38.95  3.073806              15.9  21.5  18.35  1.338043
# 3  58.0  49.55  3.339256              16.4  20.8  18.45  1.135395
# 4  59.6  47.25  3.086123              13.1  17.3  15.00  0.996447
#
#   Flipper Length (mm)                         Body Mass (g)                  \
#                   min    max median       std           min     max  median
# 0          172.000000  203.0  189.5  6.729247        2850.0  4775.0  3750.0
# 1          178.000000  208.0  190.0  6.585083        2900.0  4650.0  3575.0
# 2          176.000000  210.0  191.0  6.316310        2900.0  4700.0  3700.0
# 3          178.000000  212.0  196.0  7.131894        2700.0  4800.0  3700.0
# 4          200.915205  231.0  216.0  6.621801        3950.0  6300.0  5000.0
#
#
#           std
# 0  487.733722
# 1  455.146437
# 2  446.044441
# 3  384.335081
# 4  508.164382

# %% [markdown]
# Ví dụ về việc đếm số lượng các giá trị duy nhất ('Individual ID') trong mỗi nhóm Species và Island có thể giúp chúng ta hiểu về sự đa dạng của các cá thể được ghi nhận.

# %%
# Aggregation Example: Count unique Individual IDs by Species and Island
unique_id_count_df = df.groupby(['Species', 'Island'])['Individual ID'].nunique().reset_index(name='Unique Individual IDs')

print("Number of unique Individual IDs by Species and Island:")
display(unique_id_count_df)
# Out:
# Number of unique Individual IDs by Species and Island:
#                                      Species     Island  Unique Individual IDs
# 0        Adelie Penguin (Pygoscelis adeliae)     Biscoe                     44
# 1        Adelie Penguin (Pygoscelis adeliae)      Dream                     56
# 2        Adelie Penguin (Pygoscelis adeliae)  Torgersen                     52
# 3  Chinstrap penguin (Pygoscelis antarctica)      Dream                     58
# 4          Gentoo penguin (Pygoscelis papua)     Biscoe                     94

# %% [markdown]
# Tiếp theo, chúng ta sẽ khám phá cách lọc dữ liệu. Lọc là quá trình chọn một tập hợp con các hàng hoặc cột từ DataFrame của bạn dựa trên các tiêu chí nhất định. Điều này rất cần thiết để tập trung vào các phần cụ thể của dữ liệu của bạn để phân tích sâu hơn hoặc để chuẩn bị cho việc trực quan hóa.
#
# ### Ví dụ về lọc (Filtering Examples):
#
# **1. Lọc theo một điều kiện (ví dụ: Species)**
#
# Bạn có thể lọc DataFrame để chỉ bao gồm các bản ghi của một loài chim cánh cụt cụ thể.

# %%
# Filtering Example: Filter by a specific Species
adelie_penguins = df[df['Species'] == 'Adelie Penguin (Pygoscelis adeliae)']

print("Data for Adelie Penguins:")
display(adelie_penguins.head())
# Out:
# Data for Adelie Penguins:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion   Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes 2007-11-11
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes 2007-11-11
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes 2007-11-16
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes 2007-11-16
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes 2007-11-16
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0            39.10000           18.70000           181.000000    3750.000000
# 1            39.50000           17.40000           186.000000    3800.000000
# 2            40.30000           18.00000           195.000000    3250.000000
# 3            43.92193           17.15117           200.915205    4201.754386
# 4            36.70000           19.30000           193.000000    3450.000000
#
#       Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)
# 0    MALE           8.733382         -25.686292
# 1  FEMALE           8.949560         -24.694540
# 2  FEMALE           8.368210         -25.333020
# 3    MALE           8.733382         -25.686292
# 4  FEMALE           8.766510         -25.324260

# %% [markdown]
# Tiếp theo, hãy lọc dữ liệu để chỉ hiển thị các hàng mà loài chim cánh cụt là 'Gentoo penguin (Pygoscelis papua)'. Ngoài ra, chúng ta có thể lọc dữ liệu dựa trên một điều kiện số học, chẳng hạn như 'Culmen Length (mm)' lớn hơn 50mm. Điều này cho phép chúng ta tập trung vào những con chim cánh cụt có mỏ dài hơn.

# %%
# Filtering Example: Filter by a specific Island
gentoo_penguins = df[df['Species'] == 'Gentoo penguin (Pygoscelis papua)']

print("Data for Gentoo Penguins:")
display(gentoo_penguins.head())

# Filtering Example: Filter by a numerical condition (e.g., Culmen Length > 50mm)
long_culmen_penguins = df[df['Culmen Length (mm)'] > 50]

print("\nPenguins with Culmen Length > 50mm:")
display(long_culmen_penguins.head())
# Out:
# Data for Gentoo Penguins:
#     studyName  Sample Number                            Species  Region  \
# 152   PAL0708              1  Gentoo penguin (Pygoscelis papua)  Anvers
# 153   PAL0708              2  Gentoo penguin (Pygoscelis papua)  Anvers
# 154   PAL0708              3  Gentoo penguin (Pygoscelis papua)  Anvers
# 155   PAL0708              4  Gentoo penguin (Pygoscelis papua)  Anvers
# 156   PAL0708              5  Gentoo penguin (Pygoscelis papua)  Anvers
#
#      Island               Stage Individual ID Clutch Completion   Date Egg  \
# 152  Biscoe  Adult, 1 Egg Stage         N31A1               Yes 2007-11-27
# 153  Biscoe  Adult, 1 Egg Stage         N31A2               Yes 2007-11-27
# 154  Biscoe  Adult, 1 Egg Stage         N32A1               Yes 2007-11-27
# 155  Biscoe  Adult, 1 Egg Stage         N32A2               Yes 2007-11-27
# 156  Biscoe  Adult, 1 Egg Stage         N33A1               Yes 2007-11-18
#
#      Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 152                46.1               13.2                211.0
# 153                50.0               16.3                230.0
# 154                48.7               14.1                210.0
# 155                50.0               15.2                218.0
# 156                47.6               14.5                215.0
#
#      Body Mass (g)     Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)
# 152         4500.0  FEMALE            7.99300          -25.51390
# 153         5700.0    MALE            8.14756          -25.39369
# 154         4450.0  FEMALE            8.14705          -25.46172
# 155         5700.0    MALE            8.25540          -25.40075
# 156         5400.0    MALE            8.23450          -25.54456
# Penguins with Culmen Length > 50mm:
#     studyName  Sample Number                            Species  Region  \
# 172   PAL0708             21  Gentoo penguin (Pygoscelis papua)  Anvers
# 185   PAL0708             34  Gentoo penguin (Pygoscelis papua)  Anvers
# 196   PAL0809             45  Gentoo penguin (Pygoscelis papua)  Anvers
# 199   PAL0809             48  Gentoo penguin (Pygoscelis papua)  Anvers
# 205   PAL0809             54  Gentoo penguin (Pygoscelis papua)  Anvers
#
#      Island               Stage Individual ID Clutch Completion   Date Egg  \
# 172  Biscoe  Adult, 1 Egg Stage         N41A1               Yes 2007-11-27
# 185  Biscoe  Adult, 1 Egg Stage         N56A2               Yes 2007-12-03
# 196  Biscoe  Adult, 1 Egg Stage          N8A1               Yes 2008-11-03
# 199  Biscoe  Adult, 1 Egg Stage         N11A2                No 2008-11-09
# 205  Biscoe  Adult, 1 Egg Stage         N14A2               Yes 2008-11-04
#
#      Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 172                50.2               14.3                218.0
# 185                59.6               17.0                230.0
# 196                50.5               15.9                222.0
# 199                50.5               15.9                225.0
# 205                50.1               15.0                225.0
#
#      Body Mass (g)   Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)
# 172         5700.0  MALE            7.89620          -25.37746
# 185         6050.0  MALE            7.76843          -25.68210
# 196         5550.0  MALE            8.46894          -26.60436
# 199         5400.0  MALE            8.65803          -26.57585
# 205         5000.0  MALE            8.50153          -26.61414

# %% [markdown]
# Cuối cùng, chúng ta có thể kết hợp nhiều điều kiện để lọc dữ liệu phức tạp hơn. Ví dụ, chúng ta có thể tìm kiếm chim cánh cụt cái thuộc loài 'Adelie Penguin (Pygoscelis adeliae)' và đến từ 'Biscoe' Island.

# %%
# Filtering Example: Filter by multiple conditions (e.g., Species and Sex and Island)
ad_fem_biscoe_penguins = df[(df['Species'] == 'Adelie Penguin (Pygoscelis adeliae)') &
                            (df['Sex'] == 'FEMALE') &
                            (df['Island'] == 'Biscoe')]

print("\nFemale Adelie Penguins from Biscoe Island:")
display(ad_fem_biscoe_penguins.head())
# Out:
# Female Adelie Penguins from Biscoe Island:
#    studyName  Sample Number                              Species  Region  \
# 20   PAL0708             21  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 22   PAL0708             23  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 25   PAL0708             26  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 27   PAL0708             28  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 28   PAL0708             29  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#     Island               Stage Individual ID Clutch Completion   Date Egg  \
# 20  Biscoe  Adult, 1 Egg Stage         N11A1               Yes 2007-11-12
# 22  Biscoe  Adult, 1 Egg Stage         N12A1               Yes 2007-11-12
# 25  Biscoe  Adult, 1 Egg Stage         N13A2               Yes 2007-11-10
# 27  Biscoe  Adult, 1 Egg Stage         N17A2               Yes 2007-11-12
# 28  Biscoe  Adult, 1 Egg Stage         N18A1                No 2007-11-10
#
#     Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 20                37.8               18.3                174.0         3400.0
# 22                35.9               19.2                189.0         3800.0
# 25                35.3               18.9                187.0         3800.0
# 27                40.5               17.9                187.0         3200.0
# 28                37.9               18.6                172.0         3150.0
#
#        Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)
# 20  FEMALE            8.73762          -25.09383
# 22  FEMALE            9.22286          -25.03474
# 25  FEMALE            9.21292          -24.36130
# 27  FEMALE            8.08138          -25.49448
# 28  FEMALE            8.38404          -25.19837

# %% [markdown]
# ### Lọc bằng cách sử dụng nhiều giá trị (Filtering with Multiple Values - `isin()`)
#
# Để chọn các hàng có chứa bất kỳ giá trị nào từ một danh sách các giá trị cụ thể trong một cột, bạn có thể sử dụng phương thức `isin()`. Ví dụ, chúng ta có thể lọc để hiển thị chim cánh cụt thuộc loài Adelie hoặc Gentoo.

# %%
# Filtering Example: Filter by multiple species using isin()
selected_species = ['Adelie Penguin (Pygoscelis adeliae)', 'Gentoo penguin (Pygoscelis papua)']
multi_species_penguins = df[df['Species'].isin(selected_species)]

print("\nPenguins from Adelie or Gentoo species:")
display(multi_species_penguins.head())
# Out:
# Penguins from Adelie or Gentoo species:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion   Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes 2007-11-11
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes 2007-11-11
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes 2007-11-16
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes 2007-11-16
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes 2007-11-16
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0            39.10000           18.70000           181.000000    3750.000000
# 1            39.50000           17.40000           186.000000    3800.000000
# 2            40.30000           18.00000           195.000000    3250.000000
# 3            43.92193           17.15117           200.915205    4201.754386
# 4            36.70000           19.30000           193.000000    3450.000000
#
#       Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)
# 0    MALE           8.733382         -25.686292
# 1  FEMALE           8.949560         -24.694540
# 2  FEMALE           8.368210         -25.333020
# 3    MALE           8.733382         -25.686292
# 4  FEMALE           8.766510         -25.324260

# %% [markdown]
# ### Lọc theo khoảng ngày (Filtering by Date Range)
#
# Vì chúng ta đã chuyển đổi cột 'Date Egg' thành kiểu datetime, chúng ta có thể lọc các bản ghi nằm trong một khoảng ngày cụ thể. Điều này rất hữu ích cho phân tích theo thời gian.

# %%
# Filtering Example: Filter by a date range
start_date = '2008-01-01'
end_date = '2008-12-31'
date_range_penguins = df[(df['Date Egg'] >= start_date) & (df['Date Egg'] <= end_date)]

print(f"\nPenguins with eggs laid between {start_date} and {end_date}:")
display(date_range_penguins.head())
# Out:
# Penguins with eggs laid between 2008-01-01 and 2008-12-31:
#    studyName  Sample Number                              Species  Region  \
# 50   PAL0809             51  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 51   PAL0809             52  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 52   PAL0809             53  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 53   PAL0809             54  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 54   PAL0809             55  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#     Island               Stage Individual ID Clutch Completion   Date Egg  \
# 50  Biscoe  Adult, 1 Egg Stage         N21A1               Yes 2008-11-06
# 51  Biscoe  Adult, 1 Egg Stage         N21A2               Yes 2008-11-06
# 52  Biscoe  Adult, 1 Egg Stage         N22A1               Yes 2008-11-09
# 53  Biscoe  Adult, 1 Egg Stage         N22A2               Yes 2008-11-09
# 54  Biscoe  Adult, 1 Egg Stage         N23A1               Yes 2008-11-09
#
#     Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 50                39.6               17.7                186.0         3500.0
# 51                40.1               18.9                188.0         4300.0
# 52                35.0               17.9                190.0         3450.0
# 53                42.0               19.5                200.0         4050.0
# 54                34.5               18.1                187.0         2900.0
#
#        Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)
# 50  FEMALE            8.46616          -26.12989
# 51    MALE            8.51362          -26.55602
# 52  FEMALE            8.19539          -26.17213
# 53    MALE            8.48095          -26.31460
# 54  FEMALE            8.41837          -26.54718
